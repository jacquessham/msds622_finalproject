# %%
import pandas as pd

# %%
price = pd.read_csv('../Data/price.csv')
whisky = pd.read_csv('../Data/whisky.csv')

# %%
price.head()
# Out:
#        brand                       label  vintage           region  price
# 0   Macallan              Macallan 12 Yr     12.0         Highland  54.99
# 1  Glenlivet             Glenlivet 12 Yr     12.0              NaN  25.99
# 2  Lagavulin             Lagavulin 16 Yr     16.0  Islay & Islands  69.99
# 3   Balvenie  Balvenie 12 Yr Double Wood     12.0         Speyside  45.99
# 4       Oban                  Oban 14 Yr     14.0         Highland  58.99

# %%
whisky.head()
# Out:
#   Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# 0  Aberfeldy     2          2      2          0        0      2      1      2
# 1   Aberlour     3          3      1          0        0      4      3      2
# 2     AnCnoc     1          3      2          0        0      2      0      0
# 3     Ardbeg     4          1      4          4        0      0      2      0
# 4    Ardmore     2          2      2          0        0      1      1      1
#
#    Nutty  Malty  Fruity  Floral  Postcode  LatitudeUTM  LongitudeUTM  \
# 0      2      2       2       2  PH15 2EB       286580        749680
# 1      2      3       3       2  AB38 9PJ       326340        842570
# 2      2      2       3       2  AB54 5LI       352960        839320
# 3      1      2       1       0  PA42 7EB       141560        646220
# 4      2      3       1       1  AB54 4NH       355350        829140
#
#         Lat      Lon           Region
# 0  56.62508 -3.85052         Highland
# ...

# %%
result = price.groupby(['brand'])['price'].agg(['min','max']).reset_index()
result.head()
# Out:
#        brand    min      max
# 0       A.D.  57.99   899.99
# 1  Aberfeldy  37.99   159.99
# 2   Aberlour  43.99    99.99
# 3    Ainsley  23.99   449.99
# 4  Alexander  26.99  1099.99

# %%
df = pd.merge(result,whisky, left_on='brand', right_on='Distillery', how='inner')
df
# Out:
#             brand     min       max     Distillery  Body  Sweetness  Smoky  \
# 0       Aberfeldy   37.99    159.99      Aberfeldy     2          2      2
# 1        Aberlour   43.99     99.99       Aberlour     3          3      1
# 2          AnCnoc   42.99    109.99         AnCnoc     1          3      2
# 3          Ardbeg   47.99    759.99         Ardbeg     4          1      4
# 4         Ardmore   63.99     63.99        Ardmore     2          2      2
# 5    Auchentoshan   33.99    399.99   Auchentoshan     0          2      0
# 6       Auchroisk  429.99    429.99      Auchroisk     2          3      1
# 7        Balblair   59.99   2399.99       Balblair     2          3      2
# 8       Benrinnes  444.99    444.99      Benrinnes     3          2      2
# 9       Benromach   37.99   1899.99      Benromach     2          2      2
# 10       Bladnoch   77.99    399.99       Bladnoch     1          2      1
# ...

# %%
df = df.loc[df['min'] != df['max']]

# %%
df.head()
# Out:
#           brand    min     max    Distillery  Body  Sweetness  Smoky  \
# 0     Aberfeldy  37.99  159.99     Aberfeldy     2          2      2
# 1      Aberlour  43.99   99.99      Aberlour     3          3      1
# 2        AnCnoc  42.99  109.99        AnCnoc     1          3      2
# 3        Ardbeg  47.99  759.99        Ardbeg     4          1      4
# 5  Auchentoshan  33.99  399.99  Auchentoshan     0          2      0
#
#    Medicinal  Tobacco  Honey   ...     Winey  Nutty  Malty  Fruity  Floral  \
# 0          0        0      2   ...         2      2      2       2       2
# 1          0        0      4   ...         2      2      3       3       2
# 2          0        0      2   ...         0      2      2       3       2
# 3          4        0      0   ...         0      1      2       1       0
# 5          0        0      1   ...         0      2      2       3       3
#
#    Postcode LatitudeUTM  LongitudeUTM       Lat      Lon
# ...

# %%
df[['brand','min','max','Sweetness','Smoky']].head()
# Out:
#           brand    min     max  Sweetness  Smoky
# 0     Aberfeldy  37.99  159.99          2      2
# 1      Aberlour  43.99   99.99          3      1
# 2        AnCnoc  42.99  109.99          3      2
# 3        Ardbeg  47.99  759.99          1      4
# 5  Auchentoshan  33.99  399.99          2      0

# %%
regions = price.groupby(['brand','region']).count().reset_index()

# %%
regions.to_csv('../Data/regions_raw.csv', index=False)
